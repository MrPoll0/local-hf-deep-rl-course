# %% [markdown]
# <a href="https://colab.research.google.com/github/huggingface/deep-rl-class/blob/main/notebooks/unit3/unit3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Unit 3: Deep Q-Learning with Atari Games 👾 using RL Baselines3 Zoo
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit4/thumbnail.jpg" alt="Unit 3 Thumbnail">
#
# In this notebook, **you'll train a Deep Q-Learning agent** playing Space Invaders using [RL Baselines3 Zoo](https://github.com/DLR-RM/rl-baselines3-zoo), a training framework based on [Stable-Baselines3](https://stable-baselines3.readthedocs.io/en/master/) that provides scripts for training, evaluating agents, tuning hyperparameters, plotting results and recording videos.
#
# We're using the [RL-Baselines-3 Zoo integration, a vanilla version of Deep Q-Learning](https://stable-baselines3.readthedocs.io/en/master/modules/dqn.html) with no extensions such as Double-DQN, Dueling-DQN, and Prioritized Experience Replay.
#
# ⬇️ Here is an example of what **you will achieve** ⬇️

# %%
# %%html
# <video controls autoplay><source src="https://huggingface.co/ThomasSimonini/ppo-SpaceInvadersNoFrameskip-v4/resolve/main/replay.mp4" type="video/mp4"></video>
# Out:
# <video controls autoplay><source src="https://huggingface.co/ThomasSimonini/ppo-SpaceInvadersNoFrameskip-v4/resolve/main/replay.mp4" type="video/mp4"></video>

# %% [markdown]
# ### 🎮 Environments:
#
# - [SpacesInvadersNoFrameskip-v4](https://gymnasium.farama.org/environments/atari/space_invaders/)
#
# You can see the difference between Space Invaders versions here 👉 https://gymnasium.farama.org/environments/atari/space_invaders/#variants
#
# ### 📚 RL-Library:
#
# - [RL-Baselines3-Zoo](https://github.com/DLR-RM/rl-baselines3-zoo)

# %% [markdown]
# ## Objectives of this notebook 🏆
# At the end of the notebook, you will:
# - Be able to understand deeper **how RL Baselines3 Zoo works**.
# - Be able to **push your trained agent and the code to the Hub** with a nice video replay and an evaluation score 🔥.

# %% [markdown]
# ## This notebook is from Deep Reinforcement Learning Course
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/deep-rl-course-illustration.jpg" alt="Deep RL Course illustration"/>

# %% [markdown]
# In this free course, you will:
#
# - 📖 Study Deep Reinforcement Learning in **theory and practice**.
# - 🧑‍💻 Learn to **use famous Deep RL libraries** such as Stable Baselines3, RL Baselines3 Zoo, CleanRL and Sample Factory 2.0.
# - 🤖 Train **agents in unique environments**
#
# And more check 📚 the syllabus 👉 https://simoninithomas.github.io/deep-rl-course
#
# Don’t forget to **<a href="http://eepurl.com/ic5ZUD">sign up to the course</a>** (we are collecting your email to be able to **send you the links when each Unit is published and give you information about the challenges and updates).**
#
#
# The best way to keep in touch is to join our discord server to exchange with the community and with us 👉🏻 https://discord.gg/ydHrjt3WP5

# %% [markdown]
# ## Prerequisites 🏗️
# Before diving into the notebook, you need to:
#
# 🔲 📚 **[Study Deep Q-Learning by reading Unit 3](https://huggingface.co/deep-rl-course/unit3/introduction)**  🤗

# %% [markdown]
# We're constantly trying to improve our tutorials, so **if you find some issues in this notebook**, please [open an issue on the Github Repo](https://github.com/huggingface/deep-rl-class/issues).

# %% [markdown]
# # Let's train a Deep Q-Learning agent playing Atari' Space Invaders 👾 and upload it to the Hub.
#
# We strongly recommend students **to use Google Colab for the hands-on exercises instead of running them on their personal computers**.
#
# By using Google Colab, **you can focus on learning and experimenting without worrying about the technical aspects of setting up your environments**.
#
# To validate this hands-on for the certification process, you need to push your trained model to the Hub and **get a result of >= 200**.
#
# To find your result, go to the leaderboard and find your model, **the result = mean_reward - std of reward**
#
# For more information about the certification process, check this section 👉 https://huggingface.co/deep-rl-course/en/unit0/introduction#certification-process

# %% [markdown]
# ## An advice 💡
# It's better to run this colab in a copy on your Google Drive, so that **if it timeouts** you still have the saved notebook on your Google Drive and do not need to fill everything from scratch.
#
# To do that you can either do `Ctrl + S` or `File > Save a copy in Google Drive.`
#
# Also, we're going to **train it for 90 minutes with 1M timesteps**. By typing `!nvidia-smi` will tell you what GPU you're using.
#
# And if you want to train more such 10 million steps, this will take about 9 hours, potentially resulting in Colab timing out. In that case, I recommend running this on your local computer (or somewhere else). Just click on: `File>Download`.

# %% [markdown]
# ## Set the GPU 💪
# - To **accelerate the agent's training, we'll use a GPU**. To do that, go to `Runtime > Change Runtime type`
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/gpu-step1.jpg" alt="GPU Step 1">

# %% [markdown]
# - `Hardware Accelerator > GPU`
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/gpu-step2.jpg" alt="GPU Step 2">

# %% [markdown]
# # Install RL-Baselines3 Zoo and its dependencies 📚

# %% [markdown]
# To be able to use Atari games in Gymnasium we need to install atari package. And accept-rom-license to download the rom files (games files).

# %% [markdown]
# But you needn't worry about any of this, the local Docker container has your back 🤗.

# %% [markdown]
# ## Train our Deep Q-Learning Agent to Play Space Invaders 👾
#
# To train an agent with RL-Baselines3-Zoo, we just need to do two things:
#
# 1. Create a hyperparameter config file that will contain our training hyperparameters called `dqn.yml`.
#
# This is a template example:
#
# ```
# SpaceInvadersNoFrameskip-v4:
#   env_wrapper:
#     - stable_baselines3.common.atari_wrappers.AtariWrapper
#   frame_stack: 4
#   policy: 'CnnPolicy'
#   n_timesteps: !!float 1e6
#   buffer_size: 100000
#   learning_rate: !!float 1e-4
#   batch_size: 32
#   learning_starts: 100000
#   target_update_interval: 1000
#   train_freq: 4
#   gradient_steps: 1
#   exploration_fraction: 0.1
#   exploration_final_eps: 0.01
#   # If True, you need to deactivate handle_timeout_termination
#   # in the replay_buffer_kwargs
#   optimize_memory_usage: False
# ```

# %% [markdown]
# Here we see that:
# - We use the `Atari Wrapper` that preprocess the input (Frame reduction ,grayscale, stack 4 frames)
# - We use `CnnPolicy`, since we use Convolutional layers to process the frames
# - We train it for 10 million `n_timesteps`
# - Memory (Experience Replay) size is 100000, aka the amount of experience steps you saved to train again your agent with.
#
# 💡 My advice is to **reduce the training timesteps to 1M,** which will take about 90 minutes on a P100. `!nvidia-smi` will tell you what GPU you're using. At 10 million steps, this will take about 9 hours, which could likely result in Colab timing out. I recommend running this on your local computer (or somewhere else). Just click on: `File>Download`.

# %% [markdown]
# In terms of hyperparameters optimization, my advice is to focus on these 3 hyperparameters:
# - `learning_rate`
# - `buffer_size (Experience Memory size)`
# - `batch_size`
#
# As a good practice, you need to **check the documentation to understand what each hyperparameters does**: https://stable-baselines3.readthedocs.io/en/master/modules/dqn.html#parameters

# %% [markdown]
# 2. We start the training and save the models on `logs` folder 📁
#
# - Define the algorithm after `--algo`, where we save the model after `-f` and where the hyperparameter config is after `-c`.

# %%
# !python -m rl_zoo3.train --algo dqn --env SpaceInvadersNoFrameskip-v4  -f logs  -c dqn.yml
# Out:
# ========== SpaceInvadersNoFrameskip-v4 ==========
# Seed: 629582211
# Loading hyperparameters from: dqn.yml
# Default hyperparameters for environment (ones being tuned will be overridden):
# OrderedDict([('batch_size', 32),
#              ('buffer_size', 100000),
#              ('env_wrapper',
#               ['stable_baselines3.common.atari_wrappers.AtariWrapper']),
#              ('exploration_final_eps', 0.01),
#              ('exploration_fraction', 0.1),
#              ('frame_stack', 4),
#              ('gradient_steps', 1),
#              ('learning_rate', 0.0001),
#              ('learning_starts', 100000),
#              ('n_timesteps', 1000000.0),
#              ('optimize_memory_usage', False),
#              ('policy', 'CnnPolicy'),
#              ('target_update_interval', 1000),
#              ('train_freq', 4)])
# Using 1 environments
# Creating test environment
# A.L.E: Arcade Learning Environment (version 0.11.2+ecc1138)
# [Powered by Stella]
# Stacking 4 frames
# Wrapping the env in a VecTransposeImage.
# Stacking 4 frames
# Wrapping the env in a VecTransposeImage.
# Using cuda device
# Log path: logs/dqn/SpaceInvadersNoFrameskip-v4_2
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.73e+03 |
# |    ep_rew_mean      | 330      |
# |    exploration_rate | 0.992    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 777      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 818      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.97e+03 |
# |    ep_rew_mean      | 180      |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 762      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 1158     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.73e+03 |
# |    ep_rew_mean      | 134      |
# |    exploration_rate | 0.983    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 791      |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 1679     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.15e+03 |
# |    ep_rew_mean      | 149      |
# |    exploration_rate | 0.971    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 825      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 2894     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.17e+03 |
# |    ep_rew_mean      | 151      |
# |    exploration_rate | 0.965    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 809      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 3520     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 138      |
# |    exploration_rate | 0.96     |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 816      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 4022     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.96e+03 |
# |    ep_rew_mean      | 130      |
# |    exploration_rate | 0.956    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 816      |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 4466     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.91e+03 |
# |    ep_rew_mean      | 120      |
# |    exploration_rate | 0.95     |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 823      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 5018     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.91e+03 |
# |    ep_rew_mean      | 118      |
# |    exploration_rate | 0.945    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 824      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 5586     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.93e+03 |
# |    ep_rew_mean      | 118      |
# |    exploration_rate | 0.938    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 828      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 6292     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.88e+03 |
# |    ep_rew_mean      | 117      |
# |    exploration_rate | 0.933    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 829      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 6792     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.85e+03 |
# |    ep_rew_mean      | 107      |
# |    exploration_rate | 0.928    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 830      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 7229     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.86e+03 |
# |    ep_rew_mean      | 111      |
# |    exploration_rate | 0.922    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 834      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 7859     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.82e+03 |
# |    ep_rew_mean      | 108      |
# |    exploration_rate | 0.917    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 836      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 8401     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.83e+03 |
# |    ep_rew_mean      | 107      |
# |    exploration_rate | 0.912    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 836      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 8936     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.82e+03 |
# |    ep_rew_mean      | 105      |
# |    exploration_rate | 0.906    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 837      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 9450     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.84e+03 |
# |    ep_rew_mean      | 110      |
# |    exploration_rate | 0.898    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 840      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 10272    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.9e+03  |
# |    ep_rew_mean      | 124      |
# |    exploration_rate | 0.89     |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 844      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 11119    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.87e+03 |
# |    ep_rew_mean      | 119      |
# |    exploration_rate | 0.885    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 846      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 11661    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.87e+03 |
# |    ep_rew_mean      | 119      |
# |    exploration_rate | 0.877    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 847      |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 12429    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.97e+03 |
# |    ep_rew_mean      | 140      |
# |    exploration_rate | 0.866    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 848      |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 13503    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.97e+03 |
# |    ep_rew_mean      | 139      |
# |    exploration_rate | 0.86     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 849      |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 14139    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.97e+03 |
# |    ep_rew_mean      | 138      |
# |    exploration_rate | 0.853    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 748      |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 14882    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.97e+03 |
# |    ep_rew_mean      | 137      |
# |    exploration_rate | 0.848    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 751      |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 15370    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.98e+03 |
# |    ep_rew_mean      | 140      |
# |    exploration_rate | 0.84     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 757      |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 16119    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.96e+03 |
# |    ep_rew_mean      | 138      |
# |    exploration_rate | 0.837    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 759      |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 16493    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.94e+03 |
# |    ep_rew_mean      | 136      |
# |    exploration_rate | 0.831    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 760      |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 17029    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.92e+03 |
# |    ep_rew_mean      | 134      |
# |    exploration_rate | 0.827    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 759      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 17495    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.92e+03 |
# |    ep_rew_mean      | 132      |
# |    exploration_rate | 0.819    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 759      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 18296    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.94e+03 |
# |    ep_rew_mean      | 136      |
# |    exploration_rate | 0.812    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 760      |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 18948    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 145      |
# |    exploration_rate | 0.802    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 760      |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 20046    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.97e+03 |
# |    ep_rew_mean      | 143      |
# |    exploration_rate | 0.796    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 761      |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 20628    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.96e+03 |
# |    ep_rew_mean      | 148      |
# |    exploration_rate | 0.791    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 761      |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 21101    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 154      |
# |    exploration_rate | 0.782    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 762      |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 22053    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 155      |
# |    exploration_rate | 0.772    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 766      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 22994    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2e+03    |
# |    ep_rew_mean      | 154      |
# |    exploration_rate | 0.768    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 767      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 23435    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.762    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 770      |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 24036    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 151      |
# |    exploration_rate | 0.756    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 772      |
# |    time_elapsed     | 31       |
# |    total_timesteps  | 24620    |
# ----------------------------------
# Eval num_timesteps=25000, episode_reward=116.00 +/- 24.37
# Episode length: 1761.40 +/- 279.69
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 1.76e+03 |
# |    mean_reward      | 116      |
# | rollout/            |          |
# |    exploration_rate | 0.753    |
# | time/               |          |
# |    total_timesteps  | 25000    |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 162      |
# |    exploration_rate | 0.743    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 682      |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 25967    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 162      |
# |    exploration_rate | 0.737    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 686      |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 26615    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 159      |
# |    exploration_rate | 0.732    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 688      |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 27021    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.01e+03 |
# |    ep_rew_mean      | 156      |
# |    exploration_rate | 0.727    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 690      |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 27567    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2e+03    |
# |    ep_rew_mean      | 154      |
# |    exploration_rate | 0.722    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 693      |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 28066    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2e+03    |
# |    ep_rew_mean      | 154      |
# |    exploration_rate | 0.714    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 697      |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 28906    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 158      |
# |    exploration_rate | 0.705    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 699      |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 29803    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 163      |
# |    exploration_rate | 0.696    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 701      |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 30708    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 164      |
# |    exploration_rate | 0.689    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 703      |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 31375    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 163      |
# |    exploration_rate | 0.681    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 706      |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 32198    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 162      |
# |    exploration_rate | 0.674    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 708      |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 32971    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 162      |
# |    exploration_rate | 0.666    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 709      |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 33733    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 163      |
# |    exploration_rate | 0.659    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 711      |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 34448    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 166      |
# |    exploration_rate | 0.651    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 715      |
# |    time_elapsed     | 49       |
# |    total_timesteps  | 35282    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 166      |
# |    exploration_rate | 0.645    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 682      |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 35811    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 163      |
# |    exploration_rate | 0.64     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 684      |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 36384    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 162      |
# |    exploration_rate | 0.635    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 685      |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 36841    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 162      |
# |    exploration_rate | 0.63     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 687      |
# |    time_elapsed     | 54       |
# |    total_timesteps  | 37406    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 162      |
# |    exploration_rate | 0.621    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 690      |
# |    time_elapsed     | 55       |
# |    total_timesteps  | 38314    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 165      |
# |    exploration_rate | 0.613    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 691      |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 39130    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 164      |
# |    exploration_rate | 0.607    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 693      |
# |    time_elapsed     | 57       |
# |    total_timesteps  | 39736    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 162      |
# |    exploration_rate | 0.601    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 695      |
# |    time_elapsed     | 57       |
# |    total_timesteps  | 40266    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 161      |
# |    exploration_rate | 0.596    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 696      |
# |    time_elapsed     | 58       |
# |    total_timesteps  | 40794    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 159      |
# |    exploration_rate | 0.59     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 698      |
# |    time_elapsed     | 59       |
# |    total_timesteps  | 41427    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 158      |
# |    exploration_rate | 0.584    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 699      |
# |    time_elapsed     | 60       |
# |    total_timesteps  | 42007    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 158      |
# |    exploration_rate | 0.576    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 702      |
# |    time_elapsed     | 60       |
# |    total_timesteps  | 42843    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 158      |
# |    exploration_rate | 0.568    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 705      |
# |    time_elapsed     | 61       |
# |    total_timesteps  | 43607    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 157      |
# |    exploration_rate | 0.564    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 706      |
# |    time_elapsed     | 62       |
# |    total_timesteps  | 44070    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 156      |
# |    exploration_rate | 0.557    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 708      |
# |    time_elapsed     | 63       |
# |    total_timesteps  | 44715    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 155      |
# |    exploration_rate | 0.553    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 709      |
# |    time_elapsed     | 63       |
# |    total_timesteps  | 45126    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.548    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 710      |
# |    time_elapsed     | 64       |
# |    total_timesteps  | 45646    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 154      |
# |    exploration_rate | 0.541    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 711      |
# |    time_elapsed     | 65       |
# |    total_timesteps  | 46356    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.536    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 711      |
# |    time_elapsed     | 65       |
# |    total_timesteps  | 46830    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.02e+03 |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.53     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 712      |
# |    time_elapsed     | 66       |
# |    total_timesteps  | 47452    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.01e+03 |
# |    ep_rew_mean      | 151      |
# |    exploration_rate | 0.526    |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 713      |
# |    time_elapsed     | 67       |
# |    total_timesteps  | 47863    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2e+03    |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.523    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 714      |
# |    time_elapsed     | 67       |
# |    total_timesteps  | 48196    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2e+03    |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.517    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 715      |
# |    time_elapsed     | 68       |
# |    total_timesteps  | 48791    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 148      |
# |    exploration_rate | 0.511    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 716      |
# |    time_elapsed     | 68       |
# |    total_timesteps  | 49363    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 1.99e+03 |
# |    ep_rew_mean      | 149      |
# |    exploration_rate | 0.506    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 717      |
# |    time_elapsed     | 69       |
# |    total_timesteps  | 49948    |
# ----------------------------------
# Eval num_timesteps=50000, episode_reward=241.00 +/- 83.81
# Episode length: 2511.80 +/- 355.70
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 2.51e+03 |
# |    mean_reward      | 241      |
# | rollout/            |          |
# |    exploration_rate | 0.505    |
# | time/               |          |
# |    total_timesteps  | 50000    |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.01e+03 |
# |    ep_rew_mean      | 151      |
# |    exploration_rate | 0.497    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 654      |
# |    time_elapsed     | 77       |
# |    total_timesteps  | 50795    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2e+03    |
# |    ep_rew_mean      | 151      |
# |    exploration_rate | 0.485    |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 658      |
# |    time_elapsed     | 78       |
# |    total_timesteps  | 51990    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.01e+03 |
# |    ep_rew_mean      | 153      |
# |    exploration_rate | 0.478    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 660      |
# |    time_elapsed     | 79       |
# |    total_timesteps  | 52742    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.03e+03 |
# |    ep_rew_mean      | 155      |
# |    exploration_rate | 0.47     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 662      |
# |    time_elapsed     | 80       |
# |    total_timesteps  | 53529    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 156      |
# |    exploration_rate | 0.463    |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 664      |
# |    time_elapsed     | 81       |
# |    total_timesteps  | 54242    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.04e+03 |
# |    ep_rew_mean      | 156      |
# |    exploration_rate | 0.457    |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 646      |
# |    time_elapsed     | 84       |
# |    total_timesteps  | 54872    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 157      |
# |    exploration_rate | 0.449    |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 648      |
# |    time_elapsed     | 85       |
# |    total_timesteps  | 55607    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 158      |
# |    exploration_rate | 0.44     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 650      |
# |    time_elapsed     | 87       |
# |    total_timesteps  | 56590    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 159      |
# |    exploration_rate | 0.432    |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 652      |
# |    time_elapsed     | 87       |
# |    total_timesteps  | 57400    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 164      |
# |    exploration_rate | 0.424    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 654      |
# |    time_elapsed     | 89       |
# |    total_timesteps  | 58221    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 163      |
# |    exploration_rate | 0.417    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 654      |
# |    time_elapsed     | 90       |
# |    total_timesteps  | 58887    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 165      |
# |    exploration_rate | 0.41     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 655      |
# |    time_elapsed     | 90       |
# |    total_timesteps  | 59638    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 165      |
# |    exploration_rate | 0.401    |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 657      |
# |    time_elapsed     | 92       |
# |    total_timesteps  | 60496    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.11e+03 |
# |    ep_rew_mean      | 166      |
# |    exploration_rate | 0.395    |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 657      |
# |    time_elapsed     | 92       |
# |    total_timesteps  | 61111    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 165      |
# |    exploration_rate | 0.388    |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 659      |
# |    time_elapsed     | 93       |
# |    total_timesteps  | 61834    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 163      |
# |    exploration_rate | 0.381    |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 660      |
# |    time_elapsed     | 94       |
# |    total_timesteps  | 62536    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.13e+03 |
# |    ep_rew_mean      | 166      |
# |    exploration_rate | 0.371    |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 662      |
# |    time_elapsed     | 95       |
# |    total_timesteps  | 63579    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.12e+03 |
# |    ep_rew_mean      | 166      |
# |    exploration_rate | 0.366    |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 663      |
# |    time_elapsed     | 96       |
# |    total_timesteps  | 64081    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 161      |
# |    exploration_rate | 0.36     |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 664      |
# |    time_elapsed     | 97       |
# |    total_timesteps  | 64688    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 161      |
# |    exploration_rate | 0.354    |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 664      |
# |    time_elapsed     | 98       |
# |    total_timesteps  | 65279    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.09e+03 |
# |    ep_rew_mean      | 161      |
# |    exploration_rate | 0.35     |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 664      |
# |    time_elapsed     | 98       |
# |    total_timesteps  | 65655    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 160      |
# |    exploration_rate | 0.346    |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 665      |
# |    time_elapsed     | 99       |
# |    total_timesteps  | 66086    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 160      |
# |    exploration_rate | 0.34     |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 666      |
# |    time_elapsed     | 99       |
# |    total_timesteps  | 66659    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 160      |
# |    exploration_rate | 0.335    |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 668      |
# |    time_elapsed     | 100      |
# |    total_timesteps  | 67179    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 161      |
# |    exploration_rate | 0.329    |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 669      |
# |    time_elapsed     | 101      |
# |    total_timesteps  | 67827    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 161      |
# |    exploration_rate | 0.322    |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 670      |
# |    time_elapsed     | 102      |
# |    total_timesteps  | 68456    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 165      |
# |    exploration_rate | 0.311    |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 673      |
# |    time_elapsed     | 103      |
# |    total_timesteps  | 69612    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 165      |
# |    exploration_rate | 0.305    |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 673      |
# |    time_elapsed     | 104      |
# |    total_timesteps  | 70226    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 160      |
# |    exploration_rate | 0.301    |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 674      |
# |    time_elapsed     | 104      |
# |    total_timesteps  | 70652    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 160      |
# |    exploration_rate | 0.292    |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 675      |
# |    time_elapsed     | 105      |
# |    total_timesteps  | 71531    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.1e+03  |
# |    ep_rew_mean      | 160      |
# |    exploration_rate | 0.284    |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 676      |
# |    time_elapsed     | 106      |
# |    total_timesteps  | 72320    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 155      |
# |    exploration_rate | 0.278    |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 677      |
# |    time_elapsed     | 107      |
# |    total_timesteps  | 72906    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 155      |
# |    exploration_rate | 0.272    |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 677      |
# |    time_elapsed     | 108      |
# |    total_timesteps  | 73553    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 154      |
# |    exploration_rate | 0.266    |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 678      |
# |    time_elapsed     | 109      |
# |    total_timesteps  | 74174    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 155      |
# |    exploration_rate | 0.26     |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 678      |
# |    time_elapsed     | 110      |
# |    total_timesteps  | 74710    |
# ----------------------------------
# Eval num_timesteps=75000, episode_reward=192.00 +/- 60.55
# Episode length: 2529.40 +/- 427.16
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 2.53e+03 |
# |    mean_reward      | 192      |
# | rollout/            |          |
# |    exploration_rate | 0.258    |
# | time/               |          |
# |    total_timesteps  | 75000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.07e+03 |
# |    ep_rew_mean      | 155      |
# |    exploration_rate | 0.253    |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 621      |
# |    time_elapsed     | 121      |
# |    total_timesteps  | 75426    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 151      |
# |    exploration_rate | 0.246    |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 623      |
# |    time_elapsed     | 122      |
# |    total_timesteps  | 76167    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.05e+03 |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.238    |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 625      |
# |    time_elapsed     | 123      |
# |    total_timesteps  | 76961    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.06e+03 |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.232    |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 626      |
# |    time_elapsed     | 123      |
# |    total_timesteps  | 77620    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 155      |
# |    exploration_rate | 0.224    |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 626      |
# |    time_elapsed     | 125      |
# |    total_timesteps  | 78371    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 156      |
# |    exploration_rate | 0.219    |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 627      |
# |    time_elapsed     | 125      |
# |    total_timesteps  | 78930    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.08e+03 |
# |    ep_rew_mean      | 155      |
# |    exploration_rate | 0.215    |
# ...
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0549   |
# |    n_updates        | 213170   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.92e+03 |
# |    ep_rew_mean      | 565      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3840     |
# |    fps              | 199      |
# |    time_elapsed     | 4785     |
# |    total_timesteps  | 954421   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.112    |
# |    n_updates        | 213605   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.97e+03 |
# |    ep_rew_mean      | 570      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3844     |
# |    fps              | 199      |
# |    time_elapsed     | 4795     |
# |    total_timesteps  | 956827   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.059    |
# |    n_updates        | 214206   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.96e+03 |
# |    ep_rew_mean      | 571      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3848     |
# |    fps              | 199      |
# |    time_elapsed     | 4805     |
# |    total_timesteps  | 959062   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0363   |
# |    n_updates        | 214765   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.96e+03 |
# |    ep_rew_mean      | 566      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3852     |
# |    fps              | 199      |
# |    time_elapsed     | 4816     |
# |    total_timesteps  | 960829   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0131   |
# |    n_updates        | 215207   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.95e+03 |
# |    ep_rew_mean      | 565      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3856     |
# |    fps              | 199      |
# |    time_elapsed     | 4820     |
# |    total_timesteps  | 961885   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0125   |
# |    n_updates        | 215471   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.93e+03 |
# |    ep_rew_mean      | 561      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3860     |
# |    fps              | 199      |
# |    time_elapsed     | 4824     |
# |    total_timesteps  | 962840   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0105   |
# |    n_updates        | 215709   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.91e+03 |
# |    ep_rew_mean      | 559      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3864     |
# |    fps              | 199      |
# |    time_elapsed     | 4832     |
# |    total_timesteps  | 964610   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0184   |
# |    n_updates        | 216152   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.93e+03 |
# |    ep_rew_mean      | 565      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3868     |
# |    fps              | 199      |
# |    time_elapsed     | 4836     |
# |    total_timesteps  | 965641   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0194   |
# |    n_updates        | 216410   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.93e+03 |
# |    ep_rew_mean      | 568      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3872     |
# |    fps              | 199      |
# |    time_elapsed     | 4848     |
# |    total_timesteps  | 967758   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00488  |
# |    n_updates        | 216939   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.93e+03 |
# |    ep_rew_mean      | 570      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3876     |
# |    fps              | 199      |
# |    time_elapsed     | 4854     |
# |    total_timesteps  | 969119   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0294   |
# |    n_updates        | 217279   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.94e+03 |
# |    ep_rew_mean      | 576      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3880     |
# |    fps              | 199      |
# |    time_elapsed     | 4863     |
# |    total_timesteps  | 971388   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0151   |
# |    n_updates        | 217846   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.91e+03 |
# |    ep_rew_mean      | 567      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3884     |
# |    fps              | 199      |
# |    time_elapsed     | 4870     |
# |    total_timesteps  | 973013   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0322   |
# |    n_updates        | 218253   |
# ----------------------------------
# Eval num_timesteps=975000, episode_reward=511.00 +/- 87.20
# Episode length: 4059.60 +/- 394.22
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 4.06e+03 |
# |    mean_reward      | 511      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 975000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00915  |
# |    n_updates        | 218749   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.95e+03 |
# |    ep_rew_mean      | 573      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3888     |
# |    fps              | 199      |
# |    time_elapsed     | 4900     |
# |    total_timesteps  | 975834   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0602   |
# |    n_updates        | 218958   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.97e+03 |
# |    ep_rew_mean      | 574      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3892     |
# |    fps              | 199      |
# |    time_elapsed     | 4907     |
# |    total_timesteps  | 977690   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0292   |
# |    n_updates        | 219422   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.97e+03 |
# |    ep_rew_mean      | 575      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3896     |
# |    fps              | 199      |
# |    time_elapsed     | 4916     |
# |    total_timesteps  | 979138   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0212   |
# |    n_updates        | 219784   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.97e+03 |
# |    ep_rew_mean      | 575      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3900     |
# |    fps              | 199      |
# |    time_elapsed     | 4921     |
# |    total_timesteps  | 980140   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0127   |
# |    n_updates        | 220034   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.94e+03 |
# |    ep_rew_mean      | 571      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3904     |
# |    fps              | 199      |
# |    time_elapsed     | 4930     |
# |    total_timesteps  | 982302   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0174   |
# |    n_updates        | 220575   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.96e+03 |
# |    ep_rew_mean      | 571      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3908     |
# |    fps              | 199      |
# |    time_elapsed     | 4936     |
# |    total_timesteps  | 983982   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0526   |
# |    n_updates        | 220995   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.96e+03 |
# |    ep_rew_mean      | 571      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3912     |
# |    fps              | 199      |
# |    time_elapsed     | 4944     |
# |    total_timesteps  | 985250   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00922  |
# |    n_updates        | 221312   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.94e+03 |
# |    ep_rew_mean      | 564      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3916     |
# |    fps              | 199      |
# |    time_elapsed     | 4949     |
# |    total_timesteps  | 986450   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0296   |
# |    n_updates        | 221612   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.94e+03 |
# |    ep_rew_mean      | 564      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3920     |
# |    fps              | 199      |
# |    time_elapsed     | 4956     |
# |    total_timesteps  | 987896   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0121   |
# |    n_updates        | 221973   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.94e+03 |
# |    ep_rew_mean      | 564      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3924     |
# |    fps              | 199      |
# |    time_elapsed     | 4962     |
# |    total_timesteps  | 989382   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0365   |
# |    n_updates        | 222345   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.98e+03 |
# |    ep_rew_mean      | 568      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3928     |
# |    fps              | 199      |
# |    time_elapsed     | 4971     |
# |    total_timesteps  | 991299   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0206   |
# |    n_updates        | 222824   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.98e+03 |
# |    ep_rew_mean      | 569      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3932     |
# |    fps              | 199      |
# |    time_elapsed     | 4978     |
# |    total_timesteps  | 992393   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.014    |
# |    n_updates        | 223098   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.97e+03 |
# |    ep_rew_mean      | 564      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3936     |
# |    fps              | 199      |
# |    time_elapsed     | 4985     |
# |    total_timesteps  | 993985   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0416   |
# |    n_updates        | 223496   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.98e+03 |
# |    ep_rew_mean      | 562      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3940     |
# |    fps              | 199      |
# |    time_elapsed     | 4992     |
# |    total_timesteps  | 996029   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.021    |
# |    n_updates        | 224007   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.96e+03 |
# |    ep_rew_mean      | 559      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3944     |
# |    fps              | 199      |
# |    time_elapsed     | 4998     |
# |    total_timesteps  | 997404   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.021    |
# |    n_updates        | 224350   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.96e+03 |
# |    ep_rew_mean      | 559      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3948     |
# |    fps              | 199      |
# |    time_elapsed     | 5003     |
# |    total_timesteps  | 998713   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0251   |
# |    n_updates        | 224678   |
# ----------------------------------
# Eval num_timesteps=1000000, episode_reward=460.00 +/- 175.98
# Episode length: 3892.40 +/- 684.37
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.89e+03 |
# |    mean_reward      | 460      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 1000000  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.013    |
# |    n_updates        | 224999   |
# ----------------------------------
# Saving to logs/dqn/SpaceInvadersNoFrameskip-v4_2

# %% [markdown]
# #### Solution

# %%
# !python -m rl_zoo3.train --algo dqn  --env SpaceInvadersNoFrameskip-v4 -f logs/ -c dqn.yml

# %% [markdown]
# ## Let's evaluate our agent 👀
# - RL-Baselines3-Zoo provides `enjoy.py`, a python script to evaluate our agent. In most RL libraries, we call the evaluation script `enjoy.py`.
# - Let's evaluate it for 5000 timesteps 🔥

# %%
# !python -m rl_zoo3.enjoy --algo dqn --env SpaceInvadersNoFrameskip-v4 --no-render --n-timesteps 5000 --folder logs/
# Out:
# Loading latest experiment, id=2
# Loading logs/dqn/SpaceInvadersNoFrameskip-v4_2/SpaceInvadersNoFrameskip-v4.zip
# A.L.E: Arcade Learning Environment (version 0.11.2+ecc1138)
# [Powered by Stella]
# Stacking 4 frames
# Atari Episode Score: 605.00
# Atari Episode Length 3817
# Atari Episode Score: 600.00
# Atari Episode Length 5121
# Atari Episode Score: 615.00
# Atari Episode Length 3436
# Atari Episode Score: 510.00
# Atari Episode Length 3039
# Atari Episode Score: 950.00
# Atari Episode Length 4201

# %% [markdown]
# #### Solution

# %%
# !python -m rl_zoo3.enjoy  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --no-render  --n-timesteps 5000  --folder logs/

# %% [markdown]
# ## Publish our trained model on the Hub 🚀
# Now that we saw we got good results after the training, we can publish our trained model on the hub 🤗 with one line of code.
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit3/space-invaders-model.gif" alt="Space Invaders model">

# %% [markdown]
# By using `rl_zoo3.push_to_hub` **you evaluate, record a replay, generate a model card of your agent and push it to the hub**.
#
# This way:
# - You can **showcase our work** 🔥
# - You can **visualize your agent playing** 👀
# - You can **share with the community an agent that others can use** 💾
# - You can **access a leaderboard 🏆 to see how well your agent is performing compared to your classmates** 👉  https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard

# %% [markdown]
# To be able to share your model with the community there are three more steps to follow:
#
# 1️⃣ (If it's not already done) create an account to HF ➡ https://huggingface.co/join
#
# 2️⃣ Sign in and then, you need to store your authentication token from the Hugging Face website.
# - Create a new token (https://huggingface.co/settings/tokens) **with write role**
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/create-token.jpg" alt="Create HF Token">

# %% [markdown]
# - Copy the token
# - Run the cell below and past the token

# %%
from huggingface_hub import notebook_login # To log to our Hugging Face account to be able to upload models to the Hub.
notebook_login()
# !git config --global credential.helper store
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# If you don't want to use a Google Colab or a Jupyter Notebook, you need to use this command instead: `huggingface-cli login`

# %% [markdown]
# 3️⃣ We're now ready to push our trained agent to the 🤗 Hub 🔥

# %% [markdown]
# Let's run push_to_hub.py file to upload our trained agent to the Hub.
#
# `--repo-name `: The name of the repo
#
# `-orga`: Your Hugging Face username
#
# `-f`: Where the trained model folder is (in our case `logs`)
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/notebooks/unit3/select-id.png" alt="Select Id">

# %%
# !python -m rl_zoo3.push_to_hub  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --repo-name dqn-SpaceInvadersNoFrameskip-v4 -orga MrPoll0 -f logs/
# Out:
# Loading latest experiment, id=2
# Loading logs/dqn/SpaceInvadersNoFrameskip-v4_2/SpaceInvadersNoFrameskip-v4.zip
# A.L.E: Arcade Learning Environment (version 0.11.2+ecc1138)
# [Powered by Stella]
# Stacking 4 frames
# Wrapping the env in a VecTransposeImage.
# Uploading to MrPoll0/dqn-SpaceInvadersNoFrameskip-v4, make sure to have the rights
# ℹ This function will save, evaluate, generate a video of your agent,
# create a model card and push everything to the hub. It might take up to some
# minutes if video generation is activated. This is a work in progress: if you
# encounter a bug, please open an issue.
# Fetching 1 files: 100%|███████████████████████████| 1/1 [00:00<00:00, 19.70it/s]
# Saving model to: hub/dqn-SpaceInvadersNoFrameskip-v4/dqn-SpaceInvadersNoFrameskip-v4
# Saving video to /tmp/tmpxub_3ai3/-step-0-to-step-1000.mp4
# MoviePy - Building video /tmp/tmpxub_3ai3/-step-0-to-step-1000.mp4.
# MoviePy - Writing video /tmp/tmpxub_3ai3/-step-0-to-step-1000.mp4
#
# MoviePy - Done !
# MoviePy - video ready /tmp/tmpxub_3ai3/-step-0-to-step-1000.mp4
# ✘ 'DummyVecEnv' object has no attribute 'video_recorder'
# ✘ We are unable to generate a replay of your agent, the package_to_hub
# process continues
# ✘ Please open an issue at
# https://github.com/huggingface/huggingface_sb3/issues
# ℹ Pushing repo dqn-SpaceInvadersNoFrameskip-v4 to the Hugging Face
# Hub
# Processing Files (0 / 0)                : |        |  0.00B /  0.00B
# New Data Upload                         : |        |  0.00B /  0.00B
#
#   ...oFrameskip-v4/pytorch_variables.pth: 100%|████|   864B /   864B
#
# Processing Files (1 / 1)                :   0%|    |   864B / 54.3MB, 1.44kB/s
#
#
#   ...NoFrameskip-v4/policy.optimizer.pth:   6%|▏   |  831kB / 13.5MB
#
#
#
#   ...ceInvadersNoFrameskip-v4/policy.pth:   6%|▏   |  831kB / 13.5MB
#
#
#
#
#   ...dqn-SpaceInvadersNoFrameskip-v4.zip:   6%|▏   | 1.68MB / 27.2MB
#
#
#
#
#
#   ...Frameskip-v4/train_eval_metrics.zip:   6%|▏   | 2.26kB / 36.7kB
#
#   ...oFrameskip-v4/pytorch_variables.pth: 100%|████|   864B /   864B
#
#
#   ...NoFrameskip-v4/policy.optimizer.pth:   6%|▏   |  831kB / 13.5MB
#
#
#
#   ...ceInvadersNoFrameskip-v4/policy.pth:   6%|▏   |  831kB / 13.5MB
#
#
#
#
#   ...dqn-SpaceInvadersNoFrameskip-v4.zip:   6%|▏   | 1.68MB / 27.2MB
#
#
#
#
#
# Processing Files (1 / 5)                :   6%|▏   | 3.34MB / 54.3MB, 4.18MB/s
# New Data Upload                         :   6%|▏   | 3.28MB / 53.3MB, 4.10MB/s
#
#   ...oFrameskip-v4/pytorch_variables.pth: 100%|████|   864B /   864B
#
#
#   ...NoFrameskip-v4/policy.optimizer.pth:   6%|▏   |  831kB / 13.5MB
#
#
#
#   ...ceInvadersNoFrameskip-v4/policy.pth:   6%|▏   |  831kB / 13.5MB
#
#
#
#
#   ...dqn-SpaceInvadersNoFrameskip-v4.zip:   6%|▏   | 1.68MB / 27.2MB
#
#
#
#
#
#   ...Frameskip-v4/train_eval_metrics.zip:   6%|▏   | 2.26kB / 36.7kB
#
#   ...oFrameskip-v4/pytorch_variables.pth: 100%|████|   864B /   864B
#
#
#   ...NoFrameskip-v4/policy.optimizer.pth:  14%|▌   | 1.87MB / 13.5MB
#
#
#
#   ...ceInvadersNoFrameskip-v4/policy.pth:  14%|▌   | 1.87MB / 13.5MB
#
#
#
#
#   ...dqn-SpaceInvadersNoFrameskip-v4.zip:  14%|▌   | 3.77MB / 27.2MB
#
#
#
#
#
# Processing Files (1 / 5)                :  14%|▌   | 7.52MB / 54.3MB, 6.26MB/s
# New Data Upload                         :  14%|▌   | 7.38MB / 53.3MB, 6.15MB/s
#
#   ...oFrameskip-v4/pytorch_variables.pth: 100%|████|   864B /   864B
#
#
#   ...NoFrameskip-v4/policy.optimizer.pth:  31%|█▏  | 4.16MB / 13.5MB
#
#
#
#   ...ceInvadersNoFrameskip-v4/policy.pth:  31%|█▏  | 4.16MB / 13.5MB
#
#
#
#
#   ...dqn-SpaceInvadersNoFrameskip-v4.zip:  31%|█▏  | 8.38MB / 27.2MB
#
#
#
#
#
# Processing Files (1 / 5)                :  31%|█▏  | 16.7MB / 54.3MB, 11.9MB/s
# New Data Upload                         :  31%|█▏  | 16.4MB / 53.3MB, 11.7MB/s
#
#   ...oFrameskip-v4/pytorch_variables.pth: 100%|████|   864B /   864B
#
#
#   ...NoFrameskip-v4/policy.optimizer.pth:  49%|█▉  | 6.65MB / 13.5MB
#
#
#
#   ...ceInvadersNoFrameskip-v4/policy.pth:  49%|█▉  | 6.65MB / 13.5MB
#
#
#
#
#   ...dqn-SpaceInvadersNoFrameskip-v4.zip:  49%|█▉  | 13.4MB / 27.2MB
#
#
#
#
#
# Processing Files (1 / 5)                :  49%|█▉  | 26.7MB / 54.3MB, 16.7MB/s
# New Data Upload                         :  49%|█▉  | 26.2MB / 53.3MB, 16.4MB/s
#
#   ...oFrameskip-v4/pytorch_variables.pth: 100%|████|   864B /   864B
#
#
#   ...NoFrameskip-v4/policy.optimizer.pth:  71%|██▊ | 9.56MB / 13.5MB
#
#
#
#   ...ceInvadersNoFrameskip-v4/policy.pth:  71%|██▊ | 9.56MB / 13.5MB
#
#
#
#
#   ...dqn-SpaceInvadersNoFrameskip-v4.zip:  71%|██▊ | 19.3MB / 27.2MB
#
#
#
#
#
# Processing Files (1 / 5)                :  71%|██▊ | 38.4MB / 54.3MB, 21.3MB/s
# New Data Upload                         :  71%|██▊ | 37.7MB / 53.3MB, 21.0MB/s
#
#   ...oFrameskip-v4/pytorch_variables.pth: 100%|████|   864B /   864B
#
#
#   ...NoFrameskip-v4/policy.optimizer.pth:  94%|███▊| 12.7MB / 13.5MB
#
#
#
#   ...ceInvadersNoFrameskip-v4/policy.pth:  94%|███▊| 12.7MB / 13.5MB
#
#
#
#
#   ...dqn-SpaceInvadersNoFrameskip-v4.zip:  94%|███▊| 25.6MB / 27.2MB
#
#
#
#
#
# Processing Files (1 / 5)                :  94%|███▊| 50.9MB / 54.3MB, 25.5MB/s
# New Data Upload                         :  94%|███▊| 50.0MB / 53.3MB, 25.0MB/s
#
#   ...oFrameskip-v4/pytorch_variables.pth: 100%|████|   864B /   864B
#
#
#   ...NoFrameskip-v4/policy.optimizer.pth:  98%|███▉| 13.3MB / 13.5MB
#
#
#
#   ...ceInvadersNoFrameskip-v4/policy.pth:  98%|███▉| 13.3MB / 13.5MB
#
#
#
#
#   ...dqn-SpaceInvadersNoFrameskip-v4.zip:  98%|███▉| 26.8MB / 27.2MB
#
#
#
#
#
# Processing Files (1 / 5)                :  98%|███▉| 53.5MB / 54.3MB, 24.3MB/s
# New Data Upload                         :  98%|███▉| 52.5MB / 53.3MB, 23.9MB/s
#
#   ...oFrameskip-v4/pytorch_variables.pth: 100%|████|   864B /   864B
#
#
#   ...NoFrameskip-v4/policy.optimizer.pth:  98%|███▉| 13.3MB / 13.5MB
#
#
#
#   ...ceInvadersNoFrameskip-v4/policy.pth:  98%|███▉| 13.3MB / 13.5MB
#
#
#
#
#   ...dqn-SpaceInvadersNoFrameskip-v4.zip:  98%|███▉| 26.8MB / 27.2MB
#
#
#
#
#
#   ...Frameskip-v4/train_eval_metrics.zip:  98%|███▉| 36.1kB / 36.7kB
#
#   ...oFrameskip-v4/pytorch_variables.pth: 100%|████|   864B /   864B
#
#
#   ...NoFrameskip-v4/policy.optimizer.pth:  98%|███▉| 13.3MB / 13.5MB
#
#
#
#   ...ceInvadersNoFrameskip-v4/policy.pth:  98%|███▉| 13.3MB / 13.5MB
#
#
#
#
#   ...dqn-SpaceInvadersNoFrameskip-v4.zip:  98%|███▉| 26.8MB / 27.2MB
#
#
#
#
#
#   ...Frameskip-v4/train_eval_metrics.zip:  98%|███▉| 36.1kB / 36.7kB
#
#   ...oFrameskip-v4/pytorch_variables.pth: 100%|████|   864B /   864B
#
#
#   ...NoFrameskip-v4/policy.optimizer.pth:  98%|███▉| 13.3MB / 13.5MB
#
#
#
#   ...ceInvadersNoFrameskip-v4/policy.pth:  98%|███▉| 13.3MB / 13.5MB
#
#
#
#
#   ...dqn-SpaceInvadersNoFrameskip-v4.zip:  98%|███▉| 26.8MB / 27.2MB
#
#
#
#
#
#   ...Frameskip-v4/train_eval_metrics.zip:  98%|███▉| 36.1kB / 36.7kB
#
#   ...oFrameskip-v4/pytorch_variables.pth: 100%|████|   864B /   864B
#
#
#   ...NoFrameskip-v4/policy.optimizer.pth: 100%|████| 13.5MB / 13.5MB
#
#
#
#   ...ceInvadersNoFrameskip-v4/policy.pth: 100%|████| 13.5MB / 13.5MB
#
#
#
#
#   ...dqn-SpaceInvadersNoFrameskip-v4.zip: 100%|████| 27.2MB / 27.2MB
#
#
#
#
#
# Processing Files (5 / 5)                : 100%|████| 54.3MB / 54.3MB, 18.1MB/s
# New Data Upload                         : 100%|████| 53.3MB / 53.3MB, 17.8MB/s
#
#   ...oFrameskip-v4/pytorch_variables.pth: 100%|████|   864B /   864B
#
#
#   ...NoFrameskip-v4/policy.optimizer.pth: 100%|████| 13.5MB / 13.5MB
#
#
#
#   ...ceInvadersNoFrameskip-v4/policy.pth: 100%|████| 13.5MB / 13.5MB
#
#
#
#
#   ...dqn-SpaceInvadersNoFrameskip-v4.zip: 100%|████| 27.2MB / 27.2MB
#
#
#
#
#
#   ...Frameskip-v4/train_eval_metrics.zip: 100%|████| 36.7kB / 36.7kB
#
#   ...oFrameskip-v4/pytorch_variables.pth: 100%|████|   864B /   864B
#
#
#   ...NoFrameskip-v4/policy.optimizer.pth: 100%|████| 13.5MB / 13.5MB
#
#
#
#   ...ceInvadersNoFrameskip-v4/policy.pth: 100%|████| 13.5MB / 13.5MB
#
#
#
#
#   ...dqn-SpaceInvadersNoFrameskip-v4.zip: 100%|████| 27.2MB / 27.2MB
#
#
#
#
#
#   ...Frameskip-v4/train_eval_metrics.zip: 100%|████| 36.7kB / 36.7kB
#
#   ...oFrameskip-v4/pytorch_variables.pth: 100%|████|   864B /   864B
#
#
#   ...NoFrameskip-v4/policy.optimizer.pth: 100%|████| 13.5MB / 13.5MB
#
#
#
#   ...ceInvadersNoFrameskip-v4/policy.pth: 100%|████| 13.5MB / 13.5MB
#
#
#
#
#   ...dqn-SpaceInvadersNoFrameskip-v4.zip: 100%|████| 27.2MB / 27.2MB
#
#
#
#
#
#   ...Frameskip-v4/train_eval_metrics.zip: 100%|████| 36.7kB / 36.7kB
#
#   ...oFrameskip-v4/pytorch_variables.pth: 100%|████|   864B /   864B
#
#
#   ...NoFrameskip-v4/policy.optimizer.pth: 100%|████| 13.5MB / 13.5MB
#
#
#
#   ...ceInvadersNoFrameskip-v4/policy.pth: 100%|████| 13.5MB / 13.5MB
#
#
#
#
#   ...dqn-SpaceInvadersNoFrameskip-v4.zip: 100%|████| 27.2MB / 27.2MB
#
#
#
#
#
#   ...Frameskip-v4/train_eval_metrics.zip: 100%|████| 36.7kB / 36.7kB
#
#   ...oFrameskip-v4/pytorch_variables.pth: 100%|████|   864B /   864B
#
#
#   ...NoFrameskip-v4/policy.optimizer.pth: 100%|████| 13.5MB / 13.5MB
#
#
#
#   ...ceInvadersNoFrameskip-v4/policy.pth: 100%|████| 13.5MB / 13.5MB
#
#
#
#
#   ...dqn-SpaceInvadersNoFrameskip-v4.zip: 100%|████| 27.2MB / 27.2MB
#
#
#
#
#
#   ...Frameskip-v4/train_eval_metrics.zip: 100%|████| 36.7kB / 36.7kB
#
#   ...oFrameskip-v4/pytorch_variables.pth: 100%|████|   864B /   864B
#
#
#   ...NoFrameskip-v4/policy.optimizer.pth: 100%|████| 13.5MB / 13.5MB
#
#
#
#   ...ceInvadersNoFrameskip-v4/policy.pth: 100%|████| 13.5MB / 13.5MB
#
#
#
#
#   ...dqn-SpaceInvadersNoFrameskip-v4.zip: 100%|████| 27.2MB / 27.2MB
#
#
#
#
#
#   ...Frameskip-v4/train_eval_metrics.zip: 100%|████| 36.7kB / 36.7kB
#
#   ...oFrameskip-v4/pytorch_variables.pth: 100%|████|   864B /   864B
#
#
#   ...NoFrameskip-v4/policy.optimizer.pth: 100%|████| 13.5MB / 13.5MB
#
#
#
#   ...ceInvadersNoFrameskip-v4/policy.pth: 100%|████| 13.5MB / 13.5MB
#
#
#
#
#   ...dqn-SpaceInvadersNoFrameskip-v4.zip: 100%|████| 27.2MB / 27.2MB
#
#
#
#
#
# Processing Files (5 / 5)                : 100%|████| 54.3MB / 54.3MB, 12.9MB/s
# New Data Upload                         : 100%|████| 53.3MB / 53.3MB, 12.7MB/s
#   ...oFrameskip-v4/pytorch_variables.pth: 100%|████|   864B /   864B
#   ...NoFrameskip-v4/policy.optimizer.pth: 100%|████| 13.5MB / 13.5MB
#   ...ceInvadersNoFrameskip-v4/policy.pth: 100%|████| 13.5MB / 13.5MB
#   ...dqn-SpaceInvadersNoFrameskip-v4.zip: 100%|████| 27.2MB / 27.2MB
#   ...Frameskip-v4/train_eval_metrics.zip: 100%|████| 36.7kB / 36.7kB
# ℹ Your model is pushed to the hub. You can view your model here:
# https://huggingface.co/MrPoll0/dqn-SpaceInvadersNoFrameskip-v4

# %% [markdown]
# #### Solution

# %%
# !python -m rl_zoo3.push_to_hub  --algo dqn  --env SpaceInvadersNoFrameskip-v4  --repo-name dqn-SpaceInvadersNoFrameskip-v4  -orga ThomasSimonini  -f logs/

# %% [markdown]
# #### Recording a video (extra, if pushing the video to the hub fails)
# With `rl_zoo3.record_video`, we can create a recording of the trained agent. The video will be saved to `logs/`.

# %%
# !python -m rl_zoo3.record_video --algo dqn --env SpaceInvadersNoFrameskip-v4 -n 1000 --folder logs/
# Out:
# Loading latest experiment, id=2
# Loading logs/dqn/SpaceInvadersNoFrameskip-v4_2/SpaceInvadersNoFrameskip-v4.zip
# A.L.E: Arcade Learning Environment (version 0.11.2+ecc1138)
# [Powered by Stella]
# Stacking 4 frames
# Loading logs/dqn/SpaceInvadersNoFrameskip-v4_2/SpaceInvadersNoFrameskip-v4.zip
# Wrapping the env in a VecTransposeImage.
# Saving video to /app/solution/logs/dqn/SpaceInvadersNoFrameskip-v4_2/videos/final-model-dqn-SpaceInvadersNoFrameskip-v4-step-0-to-step-1000.mp4
# MoviePy - Building video /app/solution/logs/dqn/SpaceInvadersNoFrameskip-v4_2/videos/final-model-dqn-SpaceInvadersNoFrameskip-v4-step-0-to-step-1000.mp4.
# MoviePy - Writing video /app/solution/logs/dqn/SpaceInvadersNoFrameskip-v4_2/videos/final-model-dqn-SpaceInvadersNoFrameskip-v4-step-0-to-step-1000.mp4
#
# MoviePy - Done !
# MoviePy - video ready /app/solution/logs/dqn/SpaceInvadersNoFrameskip-v4_2/videos/final-model-dqn-SpaceInvadersNoFrameskip-v4-step-0-to-step-1000.mp4

# %% [markdown]
# Congrats 🥳 you've just trained and uploaded your first Deep Q-Learning agent using RL-Baselines-3 Zoo. The script above should have displayed a link to a model repository such as https://huggingface.co/ThomasSimonini/dqn-SpaceInvadersNoFrameskip-v4. When you go to this link, you can:
#
# - See a **video preview of your agent** at the right.
# - Click "Files and versions" to see all the files in the repository.
# - Click "Use in stable-baselines3" to get a code snippet that shows how to load the model.
# - A model card (`README.md` file) which gives a description of the model and the hyperparameters you used.
#
# Under the hood, the Hub uses git-based repositories (don't worry if you don't know what git is), which means you can update the model with new versions as you experiment and improve your agent.
#
# **Compare the results of your agents with your classmates** using the [leaderboard](https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard) 🏆

# %% [markdown]
# ## Load a powerful trained model 🔥
# - The Stable-Baselines3 team uploaded **more than 150 trained Deep Reinforcement Learning agents on the Hub**.
#
# You can find them here: 👉 https://huggingface.co/sb3
#
# Some examples:
# - Asteroids: https://huggingface.co/sb3/dqn-AsteroidsNoFrameskip-v4
# - Beam Rider: https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4
# - Breakout: https://huggingface.co/sb3/dqn-BreakoutNoFrameskip-v4
# - Road Runner: https://huggingface.co/sb3/dqn-RoadRunnerNoFrameskip-v4
#
# Let's load an agent playing Beam Rider: https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4

# %%
# %%html
# <video controls autoplay><source src="https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4/resolve/main/replay.mp4" type="video/mp4"></video>
# Out:
# <video controls autoplay><source src="https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4/resolve/main/replay.mp4" type="video/mp4"></video>

# %% [markdown]
# 1. We download the model using `rl_zoo3.load_from_hub`, and place it in a new folder that we can call `rl_trained`

# %%
# Download model and save it into the logs/ folder
# !python -m rl_zoo3.load_from_hub --algo dqn --env BeamRiderNoFrameskip-v4 -orga sb3 -f rl_trained/
# Out:
# Downloading from https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4
# dqn-BeamRiderNoFrameskip-v4.zip: 100%|█████| 27.2M/27.2M [00:00<00:00, 34.5MB/s]
# config.yml: 100%|██████████████████████████████| 548/548 [00:00<00:00, 5.50MB/s]
# No normalization file
# args.yml: 100%|████████████████████████████████| 887/887 [00:00<00:00, 3.60MB/s]
# env_kwargs.yml: 100%|████████████████████████| 3.00/3.00 [00:00<00:00, 19.8kB/s]
# train_eval_metrics.zip: 100%|████████████████| 244k/244k [00:00<00:00, 25.2MB/s]
# Saving to rl_trained/dqn/BeamRiderNoFrameskip-v4_1

# %% [markdown]
# 2. Let's evaluate if for 5000 timesteps

# %%
# !python -m rl_zoo3.enjoy --algo dqn --env BeamRiderNoFrameskip-v4 -n 5000  -f rl_trained/ --no-render
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# Loading latest experiment, id=1
# Loading rl_trained/dqn/BeamRiderNoFrameskip-v4_1/BeamRiderNoFrameskip-v4.zip
# A.L.E: Arcade Learning Environment (version 0.11.2+ecc1138)
# [Powered by Stella]
# Stacking 4 frames
# /opt/conda/envs/base-env/lib/python3.11/site-packages/stable_baselines3/common/save_util.py:167: UserWarning: Could not deserialize object exploration_schedule. Consider using `custom_objects` argument to replace this object.
# Exception: code expected at least 16 arguments, got 15
#   warnings.warn(
# /opt/conda/envs/base-env/lib/python3.11/site-packages/stable_baselines3/common/vec_env/patch_gym.py:95: UserWarning: You loaded a model that was trained using OpenAI Gym. We strongly recommend transitioning to Gymnasium by saving that model again.
#   warnings.warn(
# /opt/conda/envs/base-env/lib/python3.11/site-packages/stable_baselines3/common/base_class.py:773: UserWarning: You are probably loading a DQN model saved with SB3 < 2.4.0, we truncated the optimizer state so you can save the model again to avoid issues in the future (see https://github.com/DLR-RM/stable-baselines3/pull/1963 for more info). Original error: loaded state dict contains a parameter group that doesn't match the size of optimizer's group
# Note: the model should still work fine, this only a warning.
#   warnings.warn(

# %% [markdown]
# 3. Let's record a video now of 1000 timesteps. This time the video will be saved to `rl_trained/`.

# %%
# !python -m rl_zoo3.record_video --algo dqn --env BeamRiderNoFrameskip-v4 -n 1000 -f rl_trained/
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# Loading latest experiment, id=1
# Loading rl_trained/dqn/BeamRiderNoFrameskip-v4_1/BeamRiderNoFrameskip-v4.zip
# A.L.E: Arcade Learning Environment (version 0.11.2+ecc1138)
# [Powered by Stella]
# Stacking 4 frames
# Loading rl_trained/dqn/BeamRiderNoFrameskip-v4_1/BeamRiderNoFrameskip-v4.zip
# /opt/conda/envs/base-env/lib/python3.11/site-packages/stable_baselines3/common/save_util.py:167: UserWarning: Could not deserialize object exploration_schedule. Consider using `custom_objects` argument to replace this object.
# Exception: code expected at least 16 arguments, got 15
#   warnings.warn(
# /opt/conda/envs/base-env/lib/python3.11/site-packages/stable_baselines3/common/vec_env/patch_gym.py:95: UserWarning: You loaded a model that was trained using OpenAI Gym. We strongly recommend transitioning to Gymnasium by saving that model again.
#   warnings.warn(
# Wrapping the env in a VecTransposeImage.
# /opt/conda/envs/base-env/lib/python3.11/site-packages/stable_baselines3/common/base_class.py:773: UserWarning: You are probably loading a DQN model saved with SB3 < 2.4.0, we truncated the optimizer state so you can save the model again to avoid issues in the future (see https://github.com/DLR-RM/stable-baselines3/pull/1963 for more info). Original error: loaded state dict contains a parameter group that doesn't match the size of optimizer's group
# Note: the model should still work fine, this only a warning.
#   warnings.warn(
# Saving video to /app/solution/rl_trained/dqn/BeamRiderNoFrameskip-v4_1/videos/final-model-dqn-BeamRiderNoFrameskip-v4-step-0-to-step-1000.mp4
# MoviePy - Building video /app/solution/rl_trained/dqn/BeamRiderNoFrameskip-v4_1/videos/final-model-dqn-BeamRiderNoFrameskip-v4-step-0-to-step-1000.mp4.
# MoviePy - Writing video /app/solution/rl_trained/dqn/BeamRiderNoFrameskip-v4_1/videos/final-model-dqn-BeamRiderNoFrameskip-v4-step-0-to-step-1000.mp4
#
# MoviePy - Done !
# MoviePy - video ready /app/solution/rl_trained/dqn/BeamRiderNoFrameskip-v4_1/videos/final-model-dqn-BeamRiderNoFrameskip-v4-step-0-to-step-1000.mp4

# %% [markdown]
# Why not trying to train your own **Deep Q-Learning Agent playing BeamRiderNoFrameskip-v4? 🏆.**
#
# If you want to try, check https://huggingface.co/sb3/dqn-BeamRiderNoFrameskip-v4#hyperparameters **in the model card, you have the hyperparameters of the trained agent.**

# %% [markdown]
# But finding hyperparameters can be a daunting task. Fortunately, we'll see in the next Unit, how we can **use Optuna for optimizing the Hyperparameters 🔥.**

# %% [markdown]
# ## Some additional challenges 🏆
# The best way to learn **is to try things by your own**!
#
# In the [Leaderboard](https://huggingface.co/spaces/huggingface-projects/Deep-Reinforcement-Learning-Leaderboard) you will find your agents. Can you get to the top?
#
# Here's a list of environments you can try to train your agent with:
# - BeamRiderNoFrameskip-v4
# - BreakoutNoFrameskip-v4
# - EnduroNoFrameskip-v4
# - PongNoFrameskip-v4
#
# Also, **if you want to learn to implement Deep Q-Learning by yourself**, you definitely should look at CleanRL implementation: https://github.com/vwxyzjn/cleanrl/blob/master/cleanrl/dqn_atari.py
#
# <img src="https://huggingface.co/datasets/huggingface-deep-rl-course/course-images/resolve/main/en/unit4/atari-envs.gif" alt="Environments"/>

# %% [markdown]
# ________________________________________________________________________
# Congrats on finishing this chapter!
#
# If you’re still feel confused with all these elements...it's totally normal! **This was the same for me and for all people who studied RL.**
#
# Take time to really **grasp the material before continuing and try the additional challenges**. It’s important to master these elements and having a solid foundations.
#
# In the next unit, **we’re going to learn about [Optuna](https://optuna.org/)**. One of the most critical task in Deep Reinforcement Learning is to find a good set of training hyperparameters. And Optuna is a library that helps you to automate the search.

# %% [markdown]
# ### This is a course built with you 👷🏿‍♀️
#
# Finally, we want to improve and update the course iteratively with your feedback. If you have some, please fill this form 👉 https://forms.gle/3HgA7bEHwAmmLfwh9
#
# We're constantly trying to improve our tutorials, so **if you find some issues in this notebook**, please [open an issue on the Github Repo](https://github.com/huggingface/deep-rl-class/issues).

# %% [markdown]
# See you on Bonus unit 2! 🔥

# %% [markdown]
# ### Keep Learning, Stay Awesome 🤗
